# %%
import psycopg2

# %%
conn = psycopg2.connect(AIVEN_DB_URI)

# %%
cur = conn.cursor()

query = "SELECT * FROM analysis"

# %%
cur.execute(query)

# %%
cur.fetchall()
# Out:
# [(1,
#   '95219d068617b374cb604c4e500ee2cf7ea65aeffbf1451fd32eaa0a4055f452_9e306b831eaef736453d654c585812f0f342a8f31562a2da21c3adf99e3de6b6_brutal',
# ...
