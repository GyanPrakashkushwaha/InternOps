# %%
import psycopg2

# %%
db_params = {
    "user": "postgres",
    "password": "password",
    "host": "localhost",
    "port": "5432",
    "database": "internops"
}

# %%
conn = psycopg2.connect(
   **db_params
)

# %%
cur = conn.cursor()

# %%
cur.execute(
    "SELECT * FROM me"
)

# %%
type(cur.fetchone())
# Out:
# NoneType

# %%
id = (1,)
id[0]
# Out:
# 1

# %%
ats_result_tuple=  (1, 1, 78, ['java', 'frontend'], ['table', 'newlines'], 'PASS', 'candiate has a strong grasp on dsa and backend systems ')

recruiter_result_tuple = (1, 1, 78, ['not 10th class', 'not dsa'], ['manipulation', 'rediness'], 'PASS', 'good candidate to hire. ')

hm_result_tuple =  (1, 1, 78, 100, 'very much aligned', 'PASS', 'Very good candidate lets hire him. ')
ats_result = {
    "match_score": ats_result_tuple[2],
    "missing_keywords": ats_result_tuple[3],
    "formatting_issues": ats_result_tuple[4],
    "decision": ats_result_tuple[5],
    "feedback": ats_result_tuple[6],
}

recruiter_result = {
    "career_progression_score": recruiter_result_tuple[2],
    "red_flags": recruiter_result_tuple[3],
    "soft_skills_detected": recruiter_result_tuple[4],
    "decision": recruiter_result_tuple[5],
    "feedback": recruiter_result_tuple[6],
}

hm_result = {
    "tech_depth_score": hm_result_tuple[2],
    "project_impact_score": hm_result_tuple[3],
    "stack_alignment": hm_result_tuple[4],
    "decision": hm_result_tuple[5],
    "feedback": hm_result_tuple[6],
}

final_result = {
    "ats_result": ats_result,
    "recruiter_result": recruiter_result,
    "hm_result": hm_result
}
print(final_result)
# Out:
# {'ats_result': {'match_score': 78, 'missing_keywords': ['java', 'frontend'], 'formatting_issues': ['table', 'newlines'], 'decision': 'PASS', 'feedback': 'candiate has a strong grasp on dsa and backend systems '}, 'recruiter_result': {'career_progression_score': 78, 'red_flags': ['not 10th class', 'not dsa'], 'soft_skills_detected': ['manipulation', 'rediness'], 'decision': 'PASS', 'feedback': 'good candidate to hire. '}, 'hm_result': {'tech_depth_score': 78, 'project_impact_score': 100, 'stack_alignment': 'very much aligned', 'decision': 'PASS', 'feedback': 'Very good candidate lets hire him. '}}

# %%
import psycopg2

# %%
AIVEN_DB_URI = "postgres://avnadmin:AVNS_LJNd7sSyeiDz6ibQa67@internopsdb-gyan02296-4a85.d.aivencloud.com:16677/defaultdb?sslmode=require"
db_params = {
    "user": "avnadmin",
    "password": "AVNS_LJNd7sSyeiDz6ibQa67",
    "host": "internopsdb-gyan02296-4a85.d.aivencloud.com",
    "port": "16677",
    "database": "defaultdb"
}
conn = psycopg2.connect(**db_params)

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM analysis")

# %%
res = cur.fetchall()

# %%
res
# Out:
# [(1,
#   '95219d068617b374cb604c4e500ee2cf7ea65aeffbf1451fd32eaa0a4055f452_9e306b831eaef736453d654c585812f0f342a8f31562a2da21c3adf99e3de6b6_brutal',
# ...
