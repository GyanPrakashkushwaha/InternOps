# %%
import psycopg2

# %%
db_params = {
    "user": "postgres",
    "password": "password",
    "host": "localhost",
    "port": "5432",
    "database": "internops"
}

# %%
conn = psycopg2.connect(
   **db_params
)

# %%
cur = conn.cursor()

# %%
cur.execute(
    "SELECT * FROM me"
)

# %%
cur.fetchall()
# Out:
# [('1', 'gyan')]
